# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from experiment import *

# %%
_ = wakapata_experiment()

# %%
experiment(lr=0.2)

# %%
experiment(lr=0.2, boader=0.01)

# %%
experiment(lr=0.2, batch_size=6)

# %%
experiment(lr=1.0)

# %%
experiment(lr=1.0, batch_size=6)

# %%
experiment(lr=1.5, batch_size=6)

# %%
experiment(lr=3.0, batch_size=6)

# %%
experiment(lr=0.01)

# %%
experiment(lr=0.01, batch_size=6)

# %%
experiment(w0=-5.0, w1=-5.0, batch_size=6)
